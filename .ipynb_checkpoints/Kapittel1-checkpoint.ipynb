# %% [markdown]
# ![image.png](attachment:df1d7bb6-a330-44b7-bf40-d3ceb96971ab.png)

# %% [markdown]
# ![image.png](attachment:08bf01b9-4e9e-41b1-b50f-8c0b4721179d.png)

# %%
tider = [0.63,0.69,0.68,0.70,0.59,0.65,0.69,0.60]

# %% [markdown]
# ![image.png](attachment:d3db20da-cdc3-487a-8e26-ca0f791582e7.png)

# %% [markdown]
# # Eksempel 1.5
# ![image.png](attachment:7cb96fa7-9ee7-476d-81da-ce5f5d3f8046.png)

# %%
# importerer to biblioteker og gir dem aliaser
import numpy as np 
import matplotlib.pyplot as plt

# Leser av data og lagrer det som en 2D array
url = 'https://raw.githubusercontent.com/LektorB/Fysikk-1/refs/heads/main/Global_temp_GISS.txt'
data = np.loadtxt(url)

# Lager 1D- arrayer av hver type data
tid = data[:,0]
temperatur = data[:,1]

plt.figure(1)
plt.plot(tid, temperatur)
plt.show()

# %% [markdown]
# ![image.png](attachment:43f476eb-9888-4166-9312-e42190bcec9a.png)

# %% [markdown]
# ![image.png](attachment:e73f3bcc-5621-40ae-b15b-0a9f87feed11.png)
# Du finner datafilene på:https://kraft.cappelendamm.no/
